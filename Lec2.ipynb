# %%
x = 5
y = 14

print(x)
print (y)

print ("x: ",x, "y: ",y)

x = 100
print ("x: ",x, "y: ",y)
# Out:
# 5
# 14
# x:  5 y:  14
# x:  100 y:  14

# %%
name = "Zara"
print("Hi!", name + ". How are you?")
# Out:
# Hi! Zara. How are you?

# %%
name, age, city = "David", 27, "New York"
print(name, age, city)
# Out:
# David 27 New York

# %%
a = b = "Hello"
print( "Value of a: "+ a)
print( "Value of b: "+ b)
# Out:
# Value of a: Hello
# Value of b: Hello

# %%
'''1. Area of a Circle: Define a constant PI = 3.14 and a variable radius. Calculate
the area of a circle using the formula area = PI * radius^2.'''

PI = 3.14
radius = int (input ("Enter the value of radius: "))
area = PI * (radius **2)

print(area)
# Out:
# Enter the value of radius: 5
# 78.5

# %%
'''2. Swapping Variables: Define two variables a = 10 and b = 20. Swap their
values without using a third variable.'''

a = 10
b = 20

a, b = b, a
print(a,b)
# Out:
# 20 10

# %%
'''3. Simple Interest Calculation: Define variables P (Principal), R (Rate of
interest), and T (Time in years). Use the formula Simple Interest = (P * R * T) /
100 to calculate the interest.'''

P =  int (input ("Enter the value of Principal: "))
R = float (input ("Enter the value of Rate of interest: ") )
T = int (input ("Enter the value of Time in years: "))

Interest = (P * R * T) / 100

print(Interest)
# Out:
# Enter the value of Principal: 100
# Enter the value of Rate of interest: 7
# Enter the value of Time in years: 3
# 21.0

# %%
'''4. Temperature Conversion: Write a Python program that defines a variable
celsius = 37. Convert this temperature to Fahrenheit using the formula
Fahrenheit = (Celsius * 9/5) + 32.'''

Celsius = 37
Fahrenheit = (Celsius * 9/5) + 32

print(Fahrenheit)
# Out:
# 98.6

# %%
'''5. Rectangle Perimeter and Area: Define two variables length and width of a
rectangle. Calculate and print both the area and the perimeter of the rectangle.'''

length_rectangle = 10
width_rectangle = 5

area = length_rectangle * width_rectangle
perimeter = 2 * (length_rectangle + width_rectangle)

print("Area of rectangle: ", area , ".\tPerimeter of rectangle: ", perimeter)
# Out:
# Area of rectangle:  50 .	Perimeter of rectangle:  30

# %%
'''1. Write a program to prompt the user for hours and rate per hour to compute
gross pay.

Enter Hours: 35

Enter Rate: 2.75

Pay: 96.25'''

hour = int(input("Hour: "))
rate = int(input("Rate: "))

pay = float(hour*rate)

print(pay)
# Out:
# Hour: 6
# Rate: 3
# 18.0

# %%
'''2. Record what happens when you print an assignment statement:

>>> print (n = 7)

How about this?

>>> print (7 + 5)

Or this?

>>> print (5.2, "this", 4 - 2, "that", 5/2.0)

Can you think of a general rule for what can follow the print statement? What
does the print statement return?'''

'''print (n = 7) //wrong'''

print (7 + 5)

print (5.2, "this", 4 - 2, "that", 5/2.0)
# Out:
# 12
# 5.2 this 2 that 2.5

# %%
'''3. Take the sentence: All work and no play makes Jack a dull boy. Store
each word in a separate variable, then print out the sentence on one line
using print.'''

sentence ="All work and no play makes Jack a dull boy."
print(sentence)

a = "All"
b = "work"
c = "and"
d = "no"
e = "play"
f = "makes"
g = "Jack"
h = "a"
i = "dull"
j = "boy."

print(a,b,c,d,e,f,g,h,i,j)
# Out:
# All work and no play makes Jack a dull boy.
# All work and no play makes Jack a dull boy.

# %%
'''4. Add parenthesis to the expression 6 * 1 - 2 to change its value from 4 to
-6.'''

a1 = (6 * 1)- 2
a2 = 6 * (1 - 2)

print("a1: ", a1)
print("a1: ", a2)
# Out:
# a1:  4
# a1:  -6

# %%
'''Exercise 2

The difference between input and raw_input is that input evaluates the input
string and raw_input does not. Try the following in the interpreter and record
what happens:

>>> x = input()

3.14

>>> type(x)

>>> x = raw_input()

3.14

>>> type(x)

>>> x = input()

'The knights who say "ni!"'

>>> x

What happens if you try the example above without the quotation marks?'''

x = input()
print(x)
type(x)
# Out:
# 3.14
# 3.14
# str

# %%
x = raw_input()
type(x)

x = input()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-a9b9e9876b8f> in <cell line: 1>()
# ----> 1 x = raw_input()
#       2 type(x)
#       3
#       4 x = input()
#
# NameError: name 'raw_input' is not defined

# %%
x = input()
print(x)
# Out:
# '3.14'

# %%
x = input()
print(x)
# Out:
# The knights who say "ni!
# The knights who say "ni!

# %%
x = raw_input()
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-c00cea096916> in <cell line: 1>()
# ----> 1 x = raw_input()
#       2 print(x)
#
# NameError: name 'raw_input' is not defined

# %%
'''6. Start the Python interpreter and enter bruc + 4 at the prompt. This will
give you an error:

NameError: name 'bruce' is not defined

Assign a value to bruce so that bruce + 4 evaluates to 10.'''

print(bruc+4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-8fbbe4bfbd1c> in <cell line: 8>()
#       6 Assign a value to bruce so that bruce + 4 evaluates to 10.'''
#       7
# ----> 8 print(bruc+4)
#
# NameError: name 'bruc' is not defined

# %%
'''6. Start the Python interpreter and enter bruce + 4 at the prompt. This will
give you an error:

NameError: name 'bruc ' is not defined

Assign a value to bruce so that bruc + 4 evaluates to 10.'''


bruc = 6
print(bruc+4)
# Out:
# 10

# %%
'''7. Write a program (Python script) named madlib.py, which asks the user to
enter a series of nouns, verbs, adjectives, adverbs, plural nouns, past tense
verbs, etc., and then generates a paragraph which is syntactically correct but
semantically ridiculous.

# Asking the user for input

noun1 = input("Enter a noun: ")

noun2 = input("Enter another noun: ")

plural_noun = input("Enter a plural noun: ")

verb_past = input("Enter a verb in past tense: ")

verb = input("Enter a verb: ")

adjective = input("Enter an adjective: ")

adverb = input("Enter an adverb: ")

# Constructing the silly paragraph

story = f"""

Once upon a time, there was a {adjective} {noun1} who loved to {verb}
{adverb}. One day, it found a group of {plural_noun} playing with a {noun2}.

The {noun1} {verb_past} with joy and decided to join them.

Together, they all {verb}ed happily ever after!

"""

'''

noun1 = input("Enter a noun: ")

noun2 = input("Enter another noun: ")

plural_noun = input("Enter a plural noun: ")

verb_past = input("Enter a verb in past tense: ")

verb = input("Enter a verb: ")

adjective = input("Enter an adjective: ")

adverb = input("Enter an adverb: ")

story = f"""

Once upon a time, there was a {adjective} {noun1} who loved to {verb}
{adverb}. One day, it found a group of {plural_noun} playing with a {noun2}.

The {noun1} {verb_past} with joy and decided to join them.

Together, they all {verb}ed happily ever after!

"""
# Out:
# Enter a noun: cat
# Enter another noun: day
# Enter a plural noun: cats
# Enter a verb in past tense: expressed
# Enter a verb: stay
# Enter an adjective: beautiful
# Enter an adverb: playful

# %%
print(story)
# Out:
# Once upon a time, there was a beautiful cat who loved to stay
# playful. One day, it found a group of cats playing with a day.
#
# The cat expressed with joy and decided to join them.
#
# Together, they all stayed happily ever after!
